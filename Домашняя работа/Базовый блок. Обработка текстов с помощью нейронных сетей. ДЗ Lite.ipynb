# %% [markdown]
# Дорогой студент!
#
# В домашнем задании Lite вам предлагается поработать подробнее с параметрами словаря и формированием гиперпараметров нейронной сети. Создайте 9 нейросетей с различными гиперпараметрами (см. пунтк 2 и 3)
#
#  Для этого необходимо:
#
#   1. Воссоздать ноутбук, аналогичный ноутбуку практической части №1, загрузив при этом необходимую нам базу (код уже доступен в ноутбуке).
#
#   2. Задать в ноутбуке следующие параметры для размера словаря, ширины окна и шага:
#
#     - Размер словаря - от 10000 до 20000 (выбрать меньшее значение диапазона, если будет перегрузка ОЗУ и перезапуск подключения к Colaboratory)
#     - Ширина окна - от 1000 до 2000
#     - Шаг - от 100 до 500 (на обучение лучше влияет наименьший шаг, но это может перегрузить ОЗУ).
#
#   3. Создать архитектуру сети и задать гиперпараметры. Можно воспользоваться шаблоном:
#
#    - Добавьте модель прямого распространения **Sequential()**
#    - Добавьте один или несколько полносвязных (**Dense**) слоёв
#    - Добавьте слои **Dropout()** и **BatchNormalization()**
#    - Добавьте выходной полносвязный слой с количеством нейронов, соответствующим количеству классов (число писателей)
#
#    Напомним, что точность сети можно проверить по значению показателя 'val_accuracy' на конце каждой эпохи.

# %%
# Загрузка датасетов из облака google
# import gdown

# %%
# Загрузка датасета из облака
# gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l7/writers.zip', None, quiet=True)

# %%
# Распаковка архива в папку writers
# !unzip -qo writers.zip -d writers/

# Просмотр содержимого папки
# !ls writers

# %%
# Ваше задание здесь
# Работа с массивами данных
import numpy as np

# Функции-утилиты для работы с категориальными данными
from tensorflow.keras import utils

# Класс для конструирования последовательной модели нейронной сети
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    SpatialDropout1D,
    BatchNormalization,
    Embedding,
    Flatten,
    Activation,
)

# Токенизатор для преобразование текстов в последовательности
from tensorflow.keras.preprocessing.text import Tokenizer

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Загрузка датасетов из облака google
import gdown

# Функции операционной системы
import os

# Работа со временем
import time

# Регулярные выражения
import re

# Запись в файлы и чтение из файлов структур данных Python
import pickle

# Отрисовка графиков
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Настройка констант для загрузки данных
FILE_DIR = "writers"  # Папка с текстовыми файлами
SIG_TRAIN = "обучающая"  # Признак обучающей выборки в имени файла
SIG_TEST = "тестовая"  # Признак тестовой выборки в имени файла

# %%
# Загрузка датасета. Добавляются имена классов и соответствующие тексты.
# Все тексты преобразуются в строку и объединяются для каждого класса и выборки
CLASS_LIST = []
text_train = []
text_test = []

for file_name in os.listdir(FILE_DIR):
    # Выделение имени класса и типа выборки из имени файла
    m = re.match(r"\((.+)\) (\S+)_", file_name)
    # Если выделение получилось, то файл обрабатывается
    if m:
        class_name = m[1]
        subset_name = m[2].lower()
        # Проверка типа выборки в имени файла
        is_train = SIG_TRAIN in subset_name
        is_test = SIG_TEST in subset_name

        # Если тип выборки обучающая либо тестовая - файл обрабатывается
        if is_train or is_test:
            # Добавление нового класса, если его еще нет в списке
            if class_name not in CLASS_LIST:
                print(f'Добавление класса "{class_name}"')
                CLASS_LIST.append(class_name)
                # Инициализация соответствующих классу строк текста
                text_train.append("")
                text_test.append("")

            # Поиск индекса класса для добавления содержимого файла в выборку
            cls = CLASS_LIST.index(class_name)
            print(
                f'Добавление файла "{file_name}" в класс "{CLASS_LIST[cls]}", {subset_name} выборка.'
            )
            with open(f"{FILE_DIR}/{file_name}", "r") as f:
                # Загрузка содержимого файла в строку
                text = f.read()
            # Определение выборки, куда будет добавлено содержимое
            subset = text_train if is_train else text_test
            # Добавление текста к соответствующей выборке класса. Концы строк заменяются на пробел
            subset[cls] += " " + text.replace("\n", " ")

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)
# Out:
# Добавление класса "Стругацкие"
# Добавление файла "(Стругацкие) Тестовая_2 вместе.txt" в класс "Стругацкие", тестовая выборка.
# Добавление класса "Рэй Брэдберри"
# Добавление файла "(Рэй Брэдберри) Обучающая_22 вместе.txt" в класс "Рэй Брэдберри", обучающая выборка.
# Добавление класса "О. Генри"
# Добавление файла "(О. Генри) Обучающая_50 вместе.txt" в класс "О. Генри", обучающая выборка.
# Добавление класса "Булгаков"
# Добавление файла "(Булгаков) Тестовая_2 вместе.txt" в класс "Булгаков", тестовая выборка.
# Добавление файла "(Булгаков) Обучающая_5 вместе.txt" в класс "Булгаков", обучающая выборка.
# Добавление класса "Макс Фрай"
# Добавление файла "(Макс Фрай) Обучающая_5 вместе.txt" в класс "Макс Фрай", обучающая выборка.
# Добавление класса "Клиффорд_Саймак"
# Добавление файла "(Клиффорд_Саймак) Обучающая_5 вместе.txt" в класс "Клиффорд_Саймак", обучающая выборка.
# Добавление файла "(О. Генри) Тестовая_20 вместе.txt" в класс "О. Генри", тестовая выборка.
# Добавление файла "(Рэй Брэдберри) Тестовая_8 вместе.txt" в класс "Рэй Брэдберри", тестовая выборка.
# Добавление файла "(Макс Фрай) Тестовая_2 вместе.txt" в класс "Макс Фрай", тестовая выборка.
# Добавление файла "(Стругацкие) Обучающая_5 вместе.txt" в класс "Стругацкие", обучающая выборка.
# Добавление файла "(Клиффорд_Саймак) Тестовая_2 вместе.txt" в класс "Клиффорд_Саймак", тестовая выборка.

# %%
# Прочитанные классы текстов
print(CLASS_LIST)

# Количество текстов в обучающей выборке
print(len(text_train))

# Количество символов в одном из текстов обучающей выборки
print(len(text_train[2]))
# Out:
# ['Стругацкие', 'Рэй Брэдберри', 'О. Генри', 'Булгаков', 'Макс Фрай', 'Клиффорд_Саймак']
# 6
# 1049518

# %%
# Проверка загрузки: вывод начальных отрывков из каждого класса
for cls in range(CLASS_COUNT):
    print(f"Класс: {CLASS_LIST[cls]}")
    print(f"  train: {text_train[cls][:200]}")
    print(f"  test : {text_test[cls][:200]}")
    print()
# Out:
# Класс: Стругацкие
#   train:  Парень из преисподней     1     Ну и деревня! Сроду я таких деревень не видел и не знал даже, что такие деревни бывают. Дома круглые, бурые, без окон, торчат на сваях, как сторожевые вышки, а под ним
#   test :  ﻿ОТЕЛЬ «У ПОГИБШЕГО АЛЬПИНИСТА»    ГЛАВА 1     Я остановил машину, вылез и снял черные очки. Все было так, как рассказывал Згут. Отель был двухэтажный, желтый с зеленым, над крыльцом красовалась трау
#
# Класс: Рэй Брэдберри
#   train:  ﻿451° по Фаренгейту   ДОНУ КОНГДОНУ С БЛАГОДАРНОСТЬЮ   Если тебе дадут линованную бумагу, пиши поперёк.  Хуан Рамон Хименес   Часть 1  ОЧАГ И САЛАМАНДРА   Жечь было наслаждением. Какое-то особое насл
#   test :  ﻿Марсианские хроники   МОЕЙ ЖЕНЕ МАРГАРЕТ С ИСКРЕННЕЙ ЛЮБОВЬЮ   «Великое дело – способность удивляться, – сказал философ. – Космические полеты снова сделали всех нас детьми».   Январь 1999  Ракетное
#
# Класс: О. Генри
#   train:  «Лиса-на-рассвете»   Коралио нежился в полуденном зное, как томная красавица в сурово хранимом гареме. Город лежал у самого моря на полоске наносной земли. Он казался брильянтиком, вкрапленным в ярко
#   test :  ﻿Багдадская птица   Без всякого сомнения, дух и гений калифа Гаруна аль-Рашида осенил маркграфа Августа-Михаила фон Паульсена Квигга.  Ресторан Квигга находится на Четвертой авеню — на улице, которую
#
# Класс: Булгаков
#   train:  ﻿Белая гвардия   Посвящается[1]  Любови Евгеньевне Белозерской[2]  Пошел мелкий снег и вдруг повалил хло-  пьями. Ветер завыл; сделалась метель.  В одно мгновение темное небо смешалось с  снежным мор
#   test :  ﻿Дон Кихот ДЕЙСТВУЮЩИЕ ЛИЦА Алонсо Кихано, он же Дон Кихот Ламанчский.  Антония – его племянница.  Ключница Дон Кихота.  Санчо Панса – оруженосец Дон Кихота.  Перо Перес – деревенский священник, лице
#
# Класс: Макс Фрай
#   train:  ﻿Власть несбывшегося   – С тех пор как меня угораздило побывать в этой грешной Черхавле, мне ежедневно снится какая-то дичь! – сердито сказал я Джуффину. – Сглазили они меня, что ли? А собственно, по
#   test :  ﻿Слишком много кошмаров    Когда балансируешь над пропастью на узкой, скользкой от крови доске, ответ на закономерный вопрос: «Как меня сюда занесло?» – вряд ли принесёт практическую пользу. Зато пои
#
# Класс: Клиффорд_Саймак
#   train:  ﻿Всё живое...     Когда я выехал из нашего городишка и повернул на шоссе, позади оказался грузовик. Этакая тяжелая громадина с прицепом, и неслась она во весь дух. Шоссе здесь срезает угол городка, и
#   test :  ﻿Зачарованное паломничество    1  Гоблин со стропил следил за прячущимся монахом, который шпионил за ученым. Гоблин ненавидел монаха и имел для этого все основания. Монах никого не ненавидел и не люб

# %%
# Задание параметров преобразования

PARAMS = ((10000, 1000, 100), (15000, 1500, 250), (20000, 2000, 500))

# %%
# Контекстный менеджер для измерения времени операций
# Операция обертывается менеджером с помощью оператора with
class timex:
    def __enter__(self):
        # Фиксация времени старта процесса
        self.t = time.time()
        return self

    def __exit__(self, type, value, traceback):
        # Вывод времени работы
        print("Время обработки: {:.2f} с".format(time.time() - self.t))

# %%
# Функция разбиения последовательности на отрезки скользящим окном
# На входе - последовательность индексов, размер окна, шаг окна
def split_sequence(sequence, win_size, hop):
    # Последовательность разбивается на части до последнего полного окна
    return [
        sequence[i : i + win_size] for i in range(0, len(sequence) - win_size + 1, hop)
    ]


# Функция формирования выборок из последовательностей индексов
# формирует выборку отрезков и соответствующих им меток классов в виде one hot encoding
def vectorize_sequence(seq_list, win_size, hop):
    # В списке последовательности следуют в порядке их классов
    # Всего последовательностей в списке ровно столько, сколько классов
    class_count = len(seq_list)

    # Списки для исходных векторов и категориальных меток класса
    x, y = [], []

    # Для каждого класса:
    for cls in range(class_count):
        # Разбиение последовательности класса cls на отрезки
        vectors = split_sequence(seq_list[cls], win_size, hop)
        # Добавление отрезков в выборку
        x += vectors
        # Для всех отрезков класса cls добавление меток класса в виде OHE
        y += [utils.to_categorical(cls, class_count)] * len(vectors)

    # Возврат результатов как numpy-массивов
    return np.array(x), np.array(y)

# %%
# Функция компиляции и обучения модели нейронной сети
def compile_train_model(
    model,
    x_train,
    y_train,
    x_val,
    y_val,
    optimizer="adam",
    epochs=50,
    batch_size=128,
    figsize=(20, 5),
):
    # Компиляция модели
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )

    # Вывод сводки
    model.summary()
    print("Start training...")
    # Обучение модели с заданными параметрами
    history = model.fit(
        x_train,
        y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_val, y_val),
        verbose=1,
    )

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle("График процесса обучения модели")
    ax1.plot(
        history.history["accuracy"], label="Доля верных ответов на обучающем наборе"
    )
    ax1.plot(
        history.history["val_accuracy"],
        label="Доля верных ответов на проверочном наборе",
    )
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel("Эпоха обучения")
    ax1.set_ylabel("Доля верных ответов")
    ax1.legend()

    ax2.plot(history.history["loss"], label="Ошибка на обучающем наборе")
    ax2.plot(history.history["val_loss"], label="Ошибка на проверочном наборе")
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel("Эпоха обучения")
    ax2.set_ylabel("Ошибка")
    ax2.legend()
    plt.show()

# Функция вывода результатов оценки модели на заданных данных
def eval_model(
    model, x, y_true, class_labels=[], cm_round=3, title="", figsize=(10, 10)
):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(
        np.argmax(y_true, axis=1), np.argmax(y_pred, axis=1), normalize="true"
    )
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f"Нейросеть {title}: матрица ошибок нормализованная", fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    plt.gca().images[-1].colorbar.remove()  # Стирание ненужной цветовой шкалы
    plt.xlabel("Предсказанные классы", fontsize=16)
    plt.ylabel("Верные классы", fontsize=16)
    fig.autofmt_xdate(rotation=45)  # Наклон меток горизонтальной оси при необходимости
    plt.show()

    print("-" * 100)
    print(f"Нейросеть: {title}")

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = "ВЕРНО :-)" if cls_pred == cls else "НЕВЕРНО :-("
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print(
            "Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}".format(
                class_labels[cls],
                100.0 * cm[cls, cls_pred],
                class_labels[cls_pred],
                msg,
            )
        )

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print(
        "\nСредняя точность распознавания: {:3.0f}%".format(
            100.0 * cm.diagonal().mean()
        )
    )


# Совместная функция обучения и оценки модели нейронной сети
def compile_train_eval_model(
    model,
    x_train,
    y_train,
    x_test,
    y_test,
    class_labels=CLASS_LIST,
    title="",
    optimizer="adam",
    epochs=50,
    batch_size=128,
    graph_size=(20, 5),
    cm_size=(10, 10),
):
    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(
        model,
        x_train,
        y_train,
        x_test,
        y_test,
        optimizer=optimizer,
        epochs=epochs,
        batch_size=batch_size,
        figsize=graph_size,
    )

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(
        model, x_test, y_test, class_labels=class_labels, title=title, figsize=cm_size
    )
    return model.evaluate(x_test, y_test)

# %%
def create_and_train_models(size, results, x_train, y_train, x_test, y_test):
    model_lite = Sequential(
        [
            Input((size,)),
            Dense(256),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(CLASS_COUNT, activation="softmax"),
        ]
    )

    model_middle = Sequential(
        [
            Input((size,)),
            Dense(256),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(128),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(CLASS_COUNT, activation="softmax"),
        ]
    )

    model_hard = Sequential(
        [
            Input((size,)),
            Dense(256),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(128),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(64),
            BatchNormalization(),
            Activation("relu"),
            Dropout(0.25),
            Dense(CLASS_COUNT, activation="softmax"),
        ]
    )

    _, acc_lite = compile_train_eval_model(
        model_lite,
        x_train,
        y_train,
        x_test,
        y_test,
        class_labels=CLASS_LIST,
        title="Lite",
    )
    _, acc_middle = compile_train_eval_model(
        model_middle,
        x_train,
        y_train,
        x_test,
        y_test,
        class_labels=CLASS_LIST,
        title="Middle",
    )
    _, acc_hard = compile_train_eval_model(
        model_hard,
        x_train,
        y_train,
        x_test,
        y_test,
        class_labels=CLASS_LIST,
        title="Hard",
    )
    results["Название модели"].extend("Lite Middle Hard".split())
    results["Количество слоев"].extend([1, 2, 3])
    results["Нейроны в 1 слое"].extend([256]*3)
    results["Точность (val_accuracy)"].extend([acc_lite, acc_middle, acc_hard])

# %%
with timex():
    results = {
        "Размер словаря": [],
        "Ширина окна": [],
        "Шаг окна": [],
        "Название модели": [],
        "Количество слоев": [],
        "Нейроны в 1 слое": [],
        "Точность (val_accuracy)": [],
    }
    for vocab_size, win_size, win_hope in PARAMS:
        results["Размер словаря"].extend([vocab_size] * 3)
        results["Ширина окна"].extend([win_size] * 3)
        results["Шаг окна"].extend([win_hope] * 3)

        # Используется встроенный в Keras токенизатор для разбиения текста и построения частотного словаря
        tokenizer = Tokenizer(
            num_words=vocab_size,
            filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
            lower=True,
            split=" ",
            oov_token="неизвестное_слово",
            char_level=False,
        )

        # Использованы параметры:
        # num_words   - объем словаря
        # filters     - убираемые из текста ненужные символы
        # lower       - приведение слов к нижнему регистру
        # split       - разделитель слов
        # char_level  - указание разделять по словам, а не по единичным символам
        # oov_token   - токен для слов, которые не вошли в словарь

        # Построение частотного словаря по обучающим текстам
        tokenizer.fit_on_texts(text_train)
        seq_train = tokenizer.texts_to_sequences(text_train)
        seq_test = tokenizer.texts_to_sequences(text_test)
        # Формирование обучающей выборки
        x_train, y_train = vectorize_sequence(seq_train, win_size, win_hope)
        # Формирование тестовой выборки
        x_test, y_test = vectorize_sequence(seq_test, win_size, win_hope)
        x_train = tokenizer.sequences_to_matrix(x_train.tolist()).astype("float16")
        x_test = tokenizer.sequences_to_matrix(x_test.tolist()).astype("float16")
        create_and_train_models(vocab_size, results, x_train, y_train, x_test, y_test)
# Out:
# I0000 00:00:1743420453.865290   26088 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │     2,560,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,562,822 (9.78 MB)
#  Trainable params: 2,562,310 (9.77 MB)
#  Non-trainable params: 512 (2.00 KB)
# Start training...
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743420463.307012   37926 service.cc:148] XLA service 0x7fb4880061b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743420463.309480   37926 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1743420463.955707   37926 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   8/138 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5756 - loss: 1.2101
# I0000 00:00:1743420466.801152   37926 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.9352 - loss: 0.2019 - val_accuracy: 0.8569 - val_loss: 0.4771
# Epoch 2/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.8145e-04 - val_accuracy: 0.8929 - val_loss: 0.3405
# Epoch 3/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 4.9930e-04 - val_accuracy: 0.8999 - val_loss: 0.3077
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 3.1856e-04 - val_accuracy: 0.9031 - val_loss: 0.2950
# Epoch 5/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.2435e-04 - val_accuracy: 0.9040 - val_loss: 0.2889
# Epoch 6/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.5605e-04 - val_accuracy: 0.9029 - val_loss: 0.2857
# Epoch 7/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.2587e-04 - val_accuracy: 0.9053 - val_loss: 0.2794
# Epoch 8/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 9.7307e-05 - val_accuracy: 0.9056 - val_loss: 0.2763
# Epoch 9/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 8.3791e-05 - val_accuracy: 0.9064 - val_loss: 0.2734
# Epoch 10/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 6.7592e-05 - val_accuracy: 0.9067 - val_loss: 0.2721
# Epoch 11/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 5.5151e-05 - val_accuracy: 0.9058 - val_loss: 0.2714
# Epoch 12/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 5.0302e-05 - val_accuracy: 0.9070 - val_loss: 0.2686
# Epoch 13/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.3630e-05 - val_accuracy: 0.9067 - val_loss: 0.2661
# Epoch 14/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.8550e-05 - val_accuracy: 0.9073 - val_loss: 0.2653
# Epoch 15/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.9995e-05 - val_accuracy: 0.9076 - val_loss: 0.2637
# Epoch 16/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.9602e-05 - val_accuracy: 0.9070 - val_loss: 0.2627
# Epoch 17/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.5069e-05 - val_accuracy: 0.9082 - val_loss: 0.2601
# Epoch 18/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.1401e-05 - val_accuracy: 0.9080 - val_loss: 0.2582
# Epoch 19/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.9183e-05 - val_accuracy: 0.9088 - val_loss: 0.2575
# Epoch 20/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.8674e-05 - val_accuracy: 0.9089 - val_loss: 0.2567
# Epoch 21/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.6408e-05 - val_accuracy: 0.9082 - val_loss: 0.2574
# Epoch 22/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.5044e-05 - val_accuracy: 0.9088 - val_loss: 0.2562
# Epoch 23/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.4557e-05 - val_accuracy: 0.9088 - val_loss: 0.2567
# Epoch 24/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1912e-05 - val_accuracy: 0.9077 - val_loss: 0.2571
# Epoch 25/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1290e-05 - val_accuracy: 0.9089 - val_loss: 0.2544
# Epoch 26/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.8198e-06 - val_accuracy: 0.9092 - val_loss: 0.2550
# Epoch 27/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.0010e-05 - val_accuracy: 0.9086 - val_loss: 0.2553
# Epoch 28/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 8.2621e-06 - val_accuracy: 0.9094 - val_loss: 0.2525
# Epoch 29/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 7.5227e-06 - val_accuracy: 0.9097 - val_loss: 0.2516
# Epoch 30/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 6.6694e-06 - val_accuracy: 0.9094 - val_loss: 0.2517
# Epoch 31/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 6.5080e-06 - val_accuracy: 0.9098 - val_loss: 0.2499
# Epoch 32/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 6.0987e-06 - val_accuracy: 0.9095 - val_loss: 0.2508
# Epoch 33/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 5.2523e-06 - val_accuracy: 0.9098 - val_loss: 0.2514
# Epoch 34/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.8917e-06 - val_accuracy: 0.9106 - val_loss: 0.2504
# Epoch 35/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.4567e-06 - val_accuracy: 0.9109 - val_loss: 0.2495
# Epoch 36/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.5859e-06 - val_accuracy: 0.9104 - val_loss: 0.2480
# Epoch 37/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.0024e-06 - val_accuracy: 0.9103 - val_loss: 0.2482
# Epoch 38/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.8565e-06 - val_accuracy: 0.9113 - val_loss: 0.2464
# Epoch 39/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.2400e-06 - val_accuracy: 0.9104 - val_loss: 0.2486
# Epoch 40/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.2505e-06 - val_accuracy: 0.9107 - val_loss: 0.2476
# Epoch 41/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.8709e-06 - val_accuracy: 0.9110 - val_loss: 0.2471
# Epoch 42/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.5004e-06 - val_accuracy: 0.9113 - val_loss: 0.2467
# Epoch 43/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.6356e-06 - val_accuracy: 0.9119 - val_loss: 0.2456
# Epoch 44/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.3733e-06 - val_accuracy: 0.9121 - val_loss: 0.2444
# Epoch 45/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.3399e-06 - val_accuracy: 0.9127 - val_loss: 0.2440
# Epoch 46/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.8206e-06 - val_accuracy: 0.9124 - val_loss: 0.2441
# Epoch 47/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.8959e-06 - val_accuracy: 0.9121 - val_loss: 0.2432
# Epoch 48/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.8578e-06 - val_accuracy: 0.9125 - val_loss: 0.2432
# Epoch 49/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.4903e-06 - val_accuracy: 0.9121 - val_loss: 0.2440
# Epoch 50/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.5440e-06 - val_accuracy: 0.9127 - val_loss: 0.2417
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Lite
# Класс: Стругацкие            89% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри         98% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              96% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              88% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             91% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       85% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  91%
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9342 - loss: 0.1849
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 256)            │     2,560,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,595,462 (9.90 MB)
#  Trainable params: 2,594,694 (9.90 MB)
#  Non-trainable params: 768 (3.00 KB)
# Start training...
# Epoch 1/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 13s 61ms/step - accuracy: 0.9000 - loss: 0.3227 - val_accuracy: 0.8597 - val_loss: 0.4875
# Epoch 2/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8886 - val_loss: 0.3545
# Epoch 3/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8968 - val_loss: 0.3183
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 9.8880e-04 - val_accuracy: 0.9010 - val_loss: 0.3009
# Epoch 5/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.8315e-04 - val_accuracy: 0.9008 - val_loss: 0.2950
# Epoch 6/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.4040e-04 - val_accuracy: 0.9023 - val_loss: 0.2878
# Epoch 7/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.6739e-04 - val_accuracy: 0.8999 - val_loss: 0.2898
# Epoch 8/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.7464e-04 - val_accuracy: 0.9020 - val_loss: 0.2864
# Epoch 9/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.4600e-04 - val_accuracy: 0.9019 - val_loss: 0.2839
# Epoch 10/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.0405e-04 - val_accuracy: 0.9010 - val_loss: 0.2844
# Epoch 11/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.6920e-04 - val_accuracy: 0.9016 - val_loss: 0.2832
# Epoch 12/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.3794e-04 - val_accuracy: 0.9029 - val_loss: 0.2785
# Epoch 13/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.2387e-04 - val_accuracy: 0.9016 - val_loss: 0.2802
# Epoch 14/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0287e-04 - val_accuracy: 0.9028 - val_loss: 0.2782
# Epoch 15/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.7737e-05 - val_accuracy: 0.9023 - val_loss: 0.2808
# Epoch 16/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.9064e-05 - val_accuracy: 0.9020 - val_loss: 0.2788
# Epoch 17/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 8.0825e-05 - val_accuracy: 0.9023 - val_loss: 0.2772
# Epoch 18/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.9986e-05 - val_accuracy: 0.9026 - val_loss: 0.2762
# Epoch 19/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.7321e-05 - val_accuracy: 0.9041 - val_loss: 0.2744
# Epoch 20/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.9956e-05 - val_accuracy: 0.9023 - val_loss: 0.2795
# Epoch 21/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.5477e-05 - val_accuracy: 0.9020 - val_loss: 0.2772
# Epoch 22/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.4823e-05 - val_accuracy: 0.9010 - val_loss: 0.2781
# Epoch 23/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.7644e-05 - val_accuracy: 0.9019 - val_loss: 0.2771
# Epoch 24/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.1171e-05 - val_accuracy: 0.9026 - val_loss: 0.2780
# Epoch 25/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.0887e-05 - val_accuracy: 0.9023 - val_loss: 0.2764
# Epoch 26/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.6257e-05 - val_accuracy: 0.9026 - val_loss: 0.2765
# Epoch 27/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.7446e-05 - val_accuracy: 0.9026 - val_loss: 0.2764
# Epoch 28/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.1549e-05 - val_accuracy: 0.9022 - val_loss: 0.2770
# Epoch 29/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.0198e-05 - val_accuracy: 0.9031 - val_loss: 0.2758
# Epoch 30/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.8883e-05 - val_accuracy: 0.9017 - val_loss: 0.2787
# Epoch 31/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.9737e-05 - val_accuracy: 0.9002 - val_loss: 0.2846
# Epoch 32/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.5676e-05 - val_accuracy: 0.9017 - val_loss: 0.2803
# Epoch 33/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.5882e-05 - val_accuracy: 0.9011 - val_loss: 0.2822
# Epoch 34/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.2057e-05 - val_accuracy: 0.9011 - val_loss: 0.2833
# Epoch 35/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.2604e-05 - val_accuracy: 0.9034 - val_loss: 0.2772
# Epoch 36/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1302e-05 - val_accuracy: 0.9052 - val_loss: 0.2732
# Epoch 37/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1958e-05 - val_accuracy: 0.9059 - val_loss: 0.2719
# Epoch 38/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 8.8879e-06 - val_accuracy: 0.9047 - val_loss: 0.2719
# Epoch 39/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.5897e-06 - val_accuracy: 0.9038 - val_loss: 0.2778
# Epoch 40/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.2201e-06 - val_accuracy: 0.9034 - val_loss: 0.2781
# Epoch 41/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0267e-05 - val_accuracy: 0.9019 - val_loss: 0.2830
# Epoch 42/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 8.8903e-06 - val_accuracy: 0.9028 - val_loss: 0.2799
# Epoch 43/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 6.5321e-06 - val_accuracy: 0.9023 - val_loss: 0.2804
# Epoch 44/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.4226e-06 - val_accuracy: 0.9032 - val_loss: 0.2777
# Epoch 45/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.7284e-06 - val_accuracy: 0.9037 - val_loss: 0.2775
# Epoch 46/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.8607e-06 - val_accuracy: 0.9043 - val_loss: 0.2756
# Epoch 47/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.0648e-06 - val_accuracy: 0.9064 - val_loss: 0.2723
# Epoch 48/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.7250e-06 - val_accuracy: 0.9062 - val_loss: 0.2729
# Epoch 49/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.3009e-06 - val_accuracy: 0.9050 - val_loss: 0.2770
# Epoch 50/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.3117e-06 - val_accuracy: 0.9044 - val_loss: 0.2808
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Middle
# Класс: Стругацкие            90% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри         97% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              96% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              85% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             90% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       85% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  91%
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9301 - loss: 0.1866
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 256)            │     2,560,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,603,590 (9.93 MB)
#  Trainable params: 2,602,694 (9.93 MB)
#  Non-trainable params: 896 (3.50 KB)
# Start training...
# Epoch 1/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 16s 63ms/step - accuracy: 0.8154 - loss: 0.6010 - val_accuracy: 0.8533 - val_loss: 0.5260
# Epoch 2/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.8907 - val_loss: 0.3494
# Epoch 3/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8993 - val_loss: 0.3061
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8974 - val_loss: 0.2961
# Epoch 5/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9001 - val_loss: 0.2801
# Epoch 6/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9010 - val_loss: 0.2786
# Epoch 7/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8993 - val_loss: 0.2811
# Epoch 8/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9029 - val_loss: 0.2744
# Epoch 9/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9017 - val_loss: 0.2789
# Epoch 10/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 7.9666e-04 - val_accuracy: 0.9026 - val_loss: 0.2736
# Epoch 11/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 6.5158e-04 - val_accuracy: 0.9020 - val_loss: 0.2788
# Epoch 12/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.4775e-04 - val_accuracy: 0.9058 - val_loss: 0.2695
# Epoch 13/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.3009e-04 - val_accuracy: 0.9046 - val_loss: 0.2733
# Epoch 14/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.4733e-04 - val_accuracy: 0.9040 - val_loss: 0.2723
# Epoch 15/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.8769e-04 - val_accuracy: 0.9076 - val_loss: 0.2673
# Epoch 16/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.3268e-04 - val_accuracy: 0.9061 - val_loss: 0.2680
# Epoch 17/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.9384e-04 - val_accuracy: 0.9070 - val_loss: 0.2698
# Epoch 18/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.5430e-04 - val_accuracy: 0.9074 - val_loss: 0.2698
# Epoch 19/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.2749e-04 - val_accuracy: 0.9079 - val_loss: 0.2694
# Epoch 20/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.2874e-04 - val_accuracy: 0.9064 - val_loss: 0.2757
# Epoch 21/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.9653e-04 - val_accuracy: 0.9035 - val_loss: 0.2864
# Epoch 22/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.6669e-04 - val_accuracy: 0.9016 - val_loss: 0.2944
# Epoch 23/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 1.4471e-04 - val_accuracy: 0.9040 - val_loss: 0.2855
# Epoch 24/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.2510e-04 - val_accuracy: 0.9074 - val_loss: 0.2772
# Epoch 25/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 1.2314e-04 - val_accuracy: 0.9058 - val_loss: 0.2822
# Epoch 26/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0197e-04 - val_accuracy: 0.9067 - val_loss: 0.2836
# Epoch 27/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0605e-04 - val_accuracy: 0.9061 - val_loss: 0.2805
# Epoch 28/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.2159e-05 - val_accuracy: 0.9049 - val_loss: 0.2871
# Epoch 29/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 7.6406e-05 - val_accuracy: 0.9041 - val_loss: 0.2931
# Epoch 30/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 8.1419e-05 - val_accuracy: 0.9059 - val_loss: 0.2911
# Epoch 31/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.9081e-05 - val_accuracy: 0.9041 - val_loss: 0.2965
# Epoch 32/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 5.7603e-05 - val_accuracy: 0.9055 - val_loss: 0.2999
# Epoch 33/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 7.3981e-05 - val_accuracy: 0.9025 - val_loss: 0.3044
# Epoch 34/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 7.5568e-05 - val_accuracy: 0.9034 - val_loss: 0.2991
# Epoch 35/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 6.9566e-05 - val_accuracy: 0.9023 - val_loss: 0.3022
# Epoch 36/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 9.9049e-05 - val_accuracy: 0.8990 - val_loss: 0.3119
# Epoch 37/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 4.2693e-05 - val_accuracy: 0.9013 - val_loss: 0.3079
# Epoch 38/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 3.8260e-05 - val_accuracy: 0.9034 - val_loss: 0.3009
# Epoch 39/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 3.5643e-05 - val_accuracy: 0.9025 - val_loss: 0.3073
# Epoch 40/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 3.1828e-05 - val_accuracy: 0.9025 - val_loss: 0.3087
# Epoch 41/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 3.8272e-05 - val_accuracy: 0.9013 - val_loss: 0.3138
# Epoch 42/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 4.4461e-05 - val_accuracy: 0.8984 - val_loss: 0.3357
# Epoch 43/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.6074e-05 - val_accuracy: 0.8934 - val_loss: 0.3568
# Epoch 44/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.1962e-05 - val_accuracy: 0.8962 - val_loss: 0.3508
# Epoch 45/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.1994e-05 - val_accuracy: 0.8961 - val_loss: 0.3517
# Epoch 46/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.9708e-05 - val_accuracy: 0.8956 - val_loss: 0.3534
# Epoch 47/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.9952e-05 - val_accuracy: 0.8969 - val_loss: 0.3464
# Epoch 48/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.9648e-05 - val_accuracy: 0.8940 - val_loss: 0.3646
# Epoch 49/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.9481e-05 - val_accuracy: 0.8926 - val_loss: 0.3675
# Epoch 50/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.6281e-05 - val_accuracy: 0.8920 - val_loss: 0.3770
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Hard
# Класс: Стругацкие            89% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри         92% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              96% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              87% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             89% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       82% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  89%
# 209/209 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9183 - loss: 0.2677
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 256)            │     3,840,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,842,822 (14.66 MB)
#  Trainable params: 3,842,310 (14.66 MB)
#  Non-trainable params: 512 (2.00 KB)
# Start training...
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.8972 - loss: 0.3309 - val_accuracy: 0.6834 - val_loss: 0.8824
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8096 - val_loss: 0.5457
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 8.7764e-04 - val_accuracy: 0.8746 - val_loss: 0.4014
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.8937 - val_loss: 0.3463
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.8997 - val_loss: 0.3230
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.9958e-04 - val_accuracy: 0.9031 - val_loss: 0.3129
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.9132e-04 - val_accuracy: 0.9042 - val_loss: 0.3072
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 2.8960e-04 - val_accuracy: 0.9069 - val_loss: 0.3032
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 2.6956e-04 - val_accuracy: 0.9087 - val_loss: 0.3010
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ -0s -3403us/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 0.8412 - val_loss: 0.4674
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.9590e-04 - val_accuracy: 0.8716 - val_loss: 0.3748
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 3.1969e-04 - val_accuracy: 0.8656 - val_loss: 0.3945
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 2.3739e-04 - val_accuracy: 0.8562 - val_loss: 0.4204
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 2.1820e-04 - val_accuracy: 0.8427 - val_loss: 0.4556
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 2.0507e-04 - val_accuracy: 0.8404 - val_loss: 0.4577
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.9472e-04 - val_accuracy: 0.8539 - val_loss: 0.4229
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.6105e-04 - val_accuracy: 0.8539 - val_loss: 0.4227
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.2925e-04 - val_accuracy: 0.8517 - val_loss: 0.4264
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.2477e-04 - val_accuracy: 0.8513 - val_loss: 0.4249
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 1.0233e-04 - val_accuracy: 0.8547 - val_loss: 0.4138
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 1.0218e-04 - val_accuracy: 0.8509 - val_loss: 0.4153
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9984 - loss: 0.0144 - val_accuracy: 0.8644 - val_loss: 0.3717
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 5.4843e-04 - val_accuracy: 0.8866 - val_loss: 0.3211
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 3.9946e-04 - val_accuracy: 0.8825 - val_loss: 0.3252
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.9594e-04 - val_accuracy: 0.8836 - val_loss: 0.3433
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9982 - loss: 0.0096 - val_accuracy: 0.8663 - val_loss: 0.3937
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.9609e-04 - val_accuracy: 0.8840 - val_loss: 0.3238
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.9414e-04 - val_accuracy: 0.8881 - val_loss: 0.3257
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9979 - loss: 0.0099 - val_accuracy: 0.8378 - val_loss: 0.4579
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9989 - loss: 0.0027 - val_accuracy: 0.8708 - val_loss: 0.3522
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 6.1536e-04 - val_accuracy: 0.8693 - val_loss: 0.3681
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.7578e-04 - val_accuracy: 0.8686 - val_loss: 0.3744
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.2675e-04 - val_accuracy: 0.8757 - val_loss: 0.3636
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.7826e-04 - val_accuracy: 0.8753 - val_loss: 0.3718
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9989 - loss: 0.0026 - val_accuracy: 0.8674 - val_loss: 0.3830
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.7938e-04 - val_accuracy: 0.8712 - val_loss: 0.3779
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.6116e-04 - val_accuracy: 0.8633 - val_loss: 0.3909
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.8663 - val_loss: 0.3889
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.2169e-04 - val_accuracy: 0.8719 - val_loss: 0.3701
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 3.2570e-04 - val_accuracy: 0.8802 - val_loss: 0.3645
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 1.6008e-04 - val_accuracy: 0.8851 - val_loss: 0.3525
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.3158e-04 - val_accuracy: 0.8885 - val_loss: 0.3454
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.8266e-05 - val_accuracy: 0.8896 - val_loss: 0.3408
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.5503e-05 - val_accuracy: 0.8911 - val_loss: 0.3375
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.6873e-05 - val_accuracy: 0.8922 - val_loss: 0.3333
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 8.3935e-05 - val_accuracy: 0.8926 - val_loss: 0.3237
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 6.0640e-05 - val_accuracy: 0.8919 - val_loss: 0.3251
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.3201e-05 - val_accuracy: 0.8949 - val_loss: 0.3192
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.8456e-05 - val_accuracy: 0.8964 - val_loss: 0.3149
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 7.1732e-05 - val_accuracy: 0.8952 - val_loss: 0.3163
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Lite
# Класс: Стругацкие            81% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри         98% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              95% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              86% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             89% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       92% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  90%
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9016 - loss: 0.2892
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                │ (None, 256)            │     3,840,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,875,462 (14.78 MB)
#  Trainable params: 3,874,694 (14.78 MB)
#  Non-trainable params: 768 (3.00 KB)
# Start training...
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.8649 - loss: 0.4536 - val_accuracy: 0.7582 - val_loss: 0.7142
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9999 - loss: 0.0092 - val_accuracy: 0.8397 - val_loss: 0.5183
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8674 - val_loss: 0.4204
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8847 - val_loss: 0.3680
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8975 - val_loss: 0.3378
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8945 - val_loss: 0.3326
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.8851 - val_loss: 0.3562
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8873 - val_loss: 0.3451
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9998 - loss: 0.0020 - val_accuracy: 0.8772 - val_loss: 0.3660
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8813 - val_loss: 0.3489
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 9.2632e-04 - val_accuracy: 0.8847 - val_loss: 0.3379
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 6.2337e-04 - val_accuracy: 0.8795 - val_loss: 0.3484
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 5.9907e-04 - val_accuracy: 0.8832 - val_loss: 0.3336
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 5.1653e-04 - val_accuracy: 0.8821 - val_loss: 0.3385
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9983 - loss: 0.0070 - val_accuracy: 0.8314 - val_loss: 0.4724
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 9.8496e-04 - val_accuracy: 0.8442 - val_loss: 0.4441
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.8603 - val_loss: 0.3946
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9993 - loss: 0.0047 - val_accuracy: 0.8442 - val_loss: 0.4172
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 8.7573e-04 - val_accuracy: 0.8385 - val_loss: 0.4376
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 5.1849e-04 - val_accuracy: 0.8490 - val_loss: 0.4215
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 4.2601e-04 - val_accuracy: 0.8460 - val_loss: 0.4303
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.4197e-04 - val_accuracy: 0.8494 - val_loss: 0.4227
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.1254e-04 - val_accuracy: 0.8524 - val_loss: 0.4141
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.7802e-04 - val_accuracy: 0.8648 - val_loss: 0.3865
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.2818e-04 - val_accuracy: 0.8686 - val_loss: 0.3793
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.8693 - val_loss: 0.3834
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ -0s -1451us/step - accuracy: 1.0000 - loss: 2.7397e-04 - val_accuracy: 0.8772 - val_loss: 0.3552
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.1702e-04 - val_accuracy: 0.8832 - val_loss: 0.3379
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.0309e-04 - val_accuracy: 0.8832 - val_loss: 0.3382
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.8023e-04 - val_accuracy: 0.8858 - val_loss: 0.3297
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.5096e-04 - val_accuracy: 0.8862 - val_loss: 0.3283
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.3349e-04 - val_accuracy: 0.8761 - val_loss: 0.3576
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.8472 - val_loss: 0.4272
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.6276e-04 - val_accuracy: 0.8637 - val_loss: 0.3844
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.7394e-04 - val_accuracy: 0.8798 - val_loss: 0.3416
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9995 - loss: 0.0034 - val_accuracy: 0.9061 - val_loss: 0.2811
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9994 - loss: 0.0038 - val_accuracy: 0.8840 - val_loss: 0.3324
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9997 - loss: 8.7356e-04 - val_accuracy: 0.8513 - val_loss: 0.4321
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9979 - loss: 0.0117 - val_accuracy: 0.7901 - val_loss: 0.6310
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.8175 - val_loss: 0.5295
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9999 - loss: 5.7484e-04 - val_accuracy: 0.8367 - val_loss: 0.4797
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.2511e-04 - val_accuracy: 0.8374 - val_loss: 0.4674
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 1.9058e-04 - val_accuracy: 0.8434 - val_loss: 0.4561
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.5251e-04 - val_accuracy: 0.8460 - val_loss: 0.4540
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.2666e-04 - val_accuracy: 0.8581 - val_loss: 0.4336
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9981 - loss: 0.0095 - val_accuracy: 0.8216 - val_loss: 0.5253
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 4.3630e-04 - val_accuracy: 0.8498 - val_loss: 0.4636
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 3.8206e-04 - val_accuracy: 0.8592 - val_loss: 0.4467
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.8573 - val_loss: 0.4493
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 2.8587e-04 - val_accuracy: 0.8543 - val_loss: 0.4655
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Middle
# Класс: Стругацкие            81% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри        100% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              92% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              78% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             81% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       88% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  87%
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8938 - loss: 0.3286
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 256)            │     3,840,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 128)            │        32,896 │
# ...
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9270 - val_loss: 0.2661
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9270 - val_loss: 0.2600
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9262 - val_loss: 0.2551
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9285 - val_loss: 0.2520
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 8.9677e-04 - val_accuracy: 0.9292 - val_loss: 0.2483
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 9.0831e-04 - val_accuracy: 0.9300 - val_loss: 0.2447
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9989 - loss: 0.0022 - val_accuracy: 0.9270 - val_loss: 0.2447
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.1198e-04 - val_accuracy: 0.9285 - val_loss: 0.2394
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.7740e-04 - val_accuracy: 0.9285 - val_loss: 0.2366
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.4054e-04 - val_accuracy: 0.9285 - val_loss: 0.2347
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.0950e-04 - val_accuracy: 0.9270 - val_loss: 0.2347
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.7823e-04 - val_accuracy: 0.9277 - val_loss: 0.2336
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.9316e-04 - val_accuracy: 0.9292 - val_loss: 0.2305
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.2763e-04 - val_accuracy: 0.9292 - val_loss: 0.2302
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.9803e-04 - val_accuracy: 0.9285 - val_loss: 0.2289
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.0370e-04 - val_accuracy: 0.9285 - val_loss: 0.2277
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 3.8748e-04 - val_accuracy: 0.9285 - val_loss: 0.2264
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.7677e-04 - val_accuracy: 0.9285 - val_loss: 0.2255
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 3.8168e-04 - val_accuracy: 0.9292 - val_loss: 0.2243
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 3.3685e-04 - val_accuracy: 0.9300 - val_loss: 0.2227
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.5754e-04 - val_accuracy: 0.9322 - val_loss: 0.2205
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.6375e-04 - val_accuracy: 0.9322 - val_loss: 0.2182
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.8592e-04 - val_accuracy: 0.9330 - val_loss: 0.2159
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.6481e-04 - val_accuracy: 0.9322 - val_loss: 0.2157
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.1781e-04 - val_accuracy: 0.9345 - val_loss: 0.2131
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.5943e-04 - val_accuracy: 0.9337 - val_loss: 0.2131
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.6464e-04 - val_accuracy: 0.9330 - val_loss: 0.2130
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.3202e-04 - val_accuracy: 0.9345 - val_loss: 0.2118
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 2.5046e-04 - val_accuracy: 0.9345 - val_loss: 0.2120
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.1659e-04 - val_accuracy: 0.9345 - val_loss: 0.2118
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.7255e-04 - val_accuracy: 0.9322 - val_loss: 0.2119
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.8647e-04 - val_accuracy: 0.9337 - val_loss: 0.2113
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.9617e-04 - val_accuracy: 0.9352 - val_loss: 0.2100
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.5155e-04 - val_accuracy: 0.9352 - val_loss: 0.2096
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.1566e-04 - val_accuracy: 0.9352 - val_loss: 0.2087
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.6932e-04 - val_accuracy: 0.9352 - val_loss: 0.2077
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3963e-04 - val_accuracy: 0.9345 - val_loss: 0.2072
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.5590e-04 - val_accuracy: 0.9345 - val_loss: 0.2067
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1977e-04 - val_accuracy: 0.9352 - val_loss: 0.2062
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.3113e-04 - val_accuracy: 0.9360 - val_loss: 0.2061
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Middle
# Класс: Стругацкие            95% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри        100% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              98% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              94% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             90% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       82% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  93%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9686 - loss: 0.1249
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 256)            │     5,120,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,163,590 (19.70 MB)
#  Trainable params: 5,162,694 (19.69 MB)
#  Non-trainable params: 896 (3.50 KB)
# Start training...
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.6044 - loss: 1.2177 - val_accuracy: 0.6950 - val_loss: 0.9332
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9932 - loss: 0.1509 - val_accuracy: 0.7726 - val_loss: 0.7048
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0664 - val_accuracy: 0.8291 - val_loss: 0.5781
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.8584 - val_loss: 0.4912
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 0.8818 - val_loss: 0.4294
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.8901 - val_loss: 0.3889
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.9021 - val_loss: 0.3544
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9998 - loss: 0.0132 - val_accuracy: 0.9014 - val_loss: 0.3358
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9059 - val_loss: 0.3199
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9127 - val_loss: 0.3048
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9172 - val_loss: 0.2955
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9172 - val_loss: 0.2867
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9194 - val_loss: 0.2784
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9194 - val_loss: 0.2744
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9232 - val_loss: 0.2682
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9262 - val_loss: 0.2578
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9277 - val_loss: 0.2524
# Epoch 18/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9285 - val_loss: 0.2499
# Epoch 19/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9277 - val_loss: 0.2488
# Epoch 20/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9270 - val_loss: 0.2457
# Epoch 21/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9277 - val_loss: 0.2437
# Epoch 22/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9277 - val_loss: 0.2428
# Epoch 23/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9285 - val_loss: 0.2410
# Epoch 24/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9270 - val_loss: 0.2423
# Epoch 25/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9285 - val_loss: 0.2378
# Epoch 26/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9277 - val_loss: 0.2378
# Epoch 27/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9262 - val_loss: 0.2383
# Epoch 28/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9255 - val_loss: 0.2361
# Epoch 29/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9277 - val_loss: 0.2337
# Epoch 30/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9270 - val_loss: 0.2313
# Epoch 31/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9300 - val_loss: 0.2260
# Epoch 32/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9307 - val_loss: 0.2216
# Epoch 33/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9292 - val_loss: 0.2275
# Epoch 34/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9322 - val_loss: 0.2223
# Epoch 35/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9322 - val_loss: 0.2196
# Epoch 36/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9322 - val_loss: 0.2172
# Epoch 37/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9330 - val_loss: 0.2157
# Epoch 38/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.1483e-04 - val_accuracy: 0.9315 - val_loss: 0.2152
# Epoch 39/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9307 - val_loss: 0.2155
# Epoch 40/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9315 - val_loss: 0.2123
# Epoch 41/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9337 - val_loss: 0.2114
# Epoch 42/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9337 - val_loss: 0.2094
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9345 - val_loss: 0.2084
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9337 - val_loss: 0.2047
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 8.6560e-04 - val_accuracy: 0.9337 - val_loss: 0.2042
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 8.2508e-04 - val_accuracy: 0.9337 - val_loss: 0.2052
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 8.2275e-04 - val_accuracy: 0.9345 - val_loss: 0.2034
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 8.2376e-04 - val_accuracy: 0.9352 - val_loss: 0.2000
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.6490e-04 - val_accuracy: 0.9352 - val_loss: 0.2004
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ -0s -13275us/step - accuracy: 1.0000 - loss: 7.2360e-04 - val_accuracy: 0.9345 - val_loss: 0.2015
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Hard
# Класс: Стругацкие            78% сеть отнесла к классу Стругацкие           - ВЕРНО :-)
# Класс: Рэй Брэдберри        100% сеть отнесла к классу Рэй Брэдберри        - ВЕРНО :-)
# Класс: О. Генри              98% сеть отнесла к классу О. Генри             - ВЕРНО :-)
# Класс: Булгаков              94% сеть отнесла к классу Булгаков             - ВЕРНО :-)
# Класс: Макс Фрай             95% сеть отнесла к классу Макс Фрай            - ВЕРНО :-)
# Класс: Клиффорд_Саймак       97% сеть отнесла к классу Клиффорд_Саймак      - ВЕРНО :-)
#
# Средняя точность распознавания:  94%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9117 - loss: 0.2436
# Время обработки: 573.36 с

# %%
import pandas as pd

# %%
df = pd.DataFrame(results)
df
# Out:
#    Размер словаря  Ширина окна  Шаг окна Название модели  Количество слоев  \
# 0           10000         1000       100            Lite                 1
# 1           10000         1000       100          Middle                 2
# 2           10000         1000       100            Hard                 3
# 3           15000         1500       250            Lite                 1
# 4           15000         1500       250          Middle                 2
# 5           15000         1500       250            Hard                 3
# 6           20000         2000       500            Lite                 1
# 7           20000         2000       500          Middle                 2
# 8           20000         2000       500            Hard                 3
#
#    Нейроны в 1 слое  Точность (val_accuracy)
# 0               256                 0.912653
# 1               256                 0.904427
# 2               256                 0.892013
# 3               256                 0.895231
# 4               256                 0.854300
# 5               256                 0.822005
# 6               256                 0.919428
# 7               256                 0.935994
# 8               256                 0.934488
